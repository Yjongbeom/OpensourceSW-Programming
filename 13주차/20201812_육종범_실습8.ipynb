# %%
# !Github URL = https://github.com/Yjongbeom/OpensourceSW-Programming.git
# Out:
# /bin/bash: line 1: Github: command not found

# %% [markdown]
# # 예제 1

# %%
a = [1,2,3]
b = a
a.append(4)
b
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# # 예제 2

# %%
class Gizmo:
    def __init__(self):
        print('Gizmo id: %d' % id(self))

x = Gizmo()
print(x)
y = Gizmo() * 10
print(y)
# Out:
# Gizmo id: 137986568134880
# <__main__.Gizmo object at 0x7d7f8060a0e0>
# Gizmo id: 137986568142512
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-4dcff79d14a0> in <cell line: 7>()
#       5 x = Gizmo()
#       6 print(x)
# ----> 7 y = Gizmo() * 10
#       8 print(y)
#
# TypeError: unsupported operand type(s) for *: 'Gizmo' and 'int'

# %%
dir()
# Out:
# ['Gizmo',
#  'In',
#  'Out',
#  '_',
#  '_1',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'a',
#  'b',
#  'exit',
#  'get_ipython',
#  'quit',
#  'x']

# %% [markdown]
# # 예제 3

# %%
charles = {'name': 'Charles L. Dodgson', 'born': 1832}

lewis = charles

print(lewis is charles)

print(id(charles), id(lewis))

lewis['balance'] = 950
print(charles)
# Out:
# True
# 137987455874112 137987455874112
# {'name': 'Charles L. Dodgson', 'born': 1832, 'balance': 950}

# %% [markdown]
# # 예제 4

# %%
alex = {'name': 'Charles L. Dodgson', 'born' : 1832, 'balance' : 950}
print(alex == charles)
print(alex is charles)
# Out:
# True
# False

# %% [markdown]
# # 예제 5

# %%
t1 = (1,2,[30,40])
t2 = (1,2,[30,40])
print(t1 == t2, t1 is t2)
print(id(t1[-1]))
t1[-1].append(99)
print(t1, id(t1[-1]))
print(t1 == t2)
# Out:
# True False
# 137986579357696
# (1, 2, [30, 40, 99]) 137986579357696
# False

# %% [markdown]
# # 예제 6

# %%
l1 = [3, [66,55,44], (7,8,9)]
l2 = list(l1)

l1.append(100)
l1[1].remove(55)
print('l1:', l1)
print('l2:', l2)

l2[1] += [33,22]
l2[2] += (10, 11)

print('l1:', l1)
print('l2:', l2)
# Out:
# l1: [3, [66, 44], (7, 8, 9), 100]
# l2: [3, [66, 44], (7, 8, 9)]
# l1: [3, [66, 44, 33, 22], (7, 8, 9), 100]
# l2: [3, [66, 44, 33, 22], (7, 8, 9, 10, 11)]

# %% [markdown]
# # 예제 7

# %%
class Bus:
    def __init__(self, passengers=None):
        if passengers is None:
            self.passengers = []
        else:
            self.passengers = list(passengers)

    def pick(self, name):
        self.passengers.append(name)

    def drop(self, name):
        self.passengers.remove(name)

# %% [markdown]
# # 예제 8

# %%
import copy
bus1 = Bus(['Alice', 'Bill', 'Claire', 'David'])
bus2 = copy.copy(bus1)
bus3 = copy.deepcopy(bus1)

print(id(bus1), id(bus2), id(bus3))

bus1.drop('Bill')
print(bus1.passengers, bus2.passengers, bus3.passengers)
print(id(bus1.passengers), id(bus2.passengers), id(bus3.passengers))
# Out:
# 137986567888592 137986567892192 137986567891520
# ['Alice', 'Claire', 'David'] ['Alice', 'Claire', 'David'] ['Alice', 'Bill', 'Claire', 'David']
# 137986564392320 137986564392320 137986564397376

# %% [markdown]
# # 예제 9

# %%
a = [10, 20]
b = [a, 30]
a.append(b)
print(a)

c = copy.deepcopy(a)
print(c)
# Out:
# [10, 20, [[...], 30]]
# [10, 20, [[...], 30]]

# %% [markdown]
# # 예제 10

# %%
def f(a,b):
    a += b
    return a

x =1
y = 2
print(f(x,y), (x,y))

a = [1,2]
b = [3,4]
print(f(a,b), (a,b))

t = (10, 20)
u = (30, 40)
print(f(t,u), (t,u))
# Out:
# 3 (1, 2)
# [1, 2, 3, 4] ([1, 2, 3, 4], [3, 4])
# (10, 20, 30, 40) ((10, 20), (30, 40))

# %% [markdown]
# # 예제 11

# %%
class HauntedBus:
    def __init__(self, passengers=[]):
        self.passengers = passengers

    def pick(self, name):
        self.passengers.append(name)

    def drop(self, name):
        self.passengers.remove(name)

# %% [markdown]
# # 에제 12

# %%
bus1 = HauntedBus(['Alice', 'Bill'])
print(bus1.passengers)

bus1.pick('Charlie')
bus1.drop('Alice')
print(bus1.passengers)

bus2 = HauntedBus()
bus2.pick('Carrie')
print(bus2.passengers)

bus3 = HauntedBus()
print(bus3.passengers)

bus3.pick('Dave')
print(bus2.passengers)

print(bus2.passengers is bus3.passengers)
print(bus1.passengers)
# Out:
# ['Alice', 'Bill']
# ['Bill', 'Charlie']
# ['Carrie']
# ['Carrie']
# ['Carrie', 'Dave']
# True
# ['Bill', 'Charlie']

# %% [markdown]
# # 예제 13

# %%
class TwilightBus:
    def __init__(self, passengers=None):
        if passengers is None:
            self.passengers = []
        else:
            self.passengers = passengers

    def pick(self, name):
        self.passengers.append(name)

    def drop(self, name):
        self.passengers.remove(name)

# %% [markdown]
# # 예제 14

# %%
basketball_team = ['Sue', 'Tina', 'Maya', 'Diana', 'Pat']
bus = TwilightBus(basketball_team)
bus.drop('Tina')
bus.drop('Pat')
print(basketball_team)
# Out:
# ['Sue', 'Maya', 'Diana']

# %% [markdown]
# # 예제 15

# %%
class TwilightBus:
    def __init__(self, passengers=None):
        if passengers is None:
            self.passengers = []
        else:
            self.passengers = list(passengers)

    def pick(self, name):
        self.passengers.append(name)

    def drop(self, name):
        self.passengers.remove(name)

# %% [markdown]
# # 예제 16

# %%
basketball_team = ['Sue', 'Tina', 'Maya', 'Diana', 'Pat']
bus = TwilightBus(basketball_team)
bus.drop('Tina')
bus.drop('Pat')
print(basketball_team)
# Out:
# ['Sue', 'Tina', 'Maya', 'Diana', 'Pat']

# %% [markdown]
# # 예제 17

# %%
import weakref

s1 = {1,2,3}
s2 = s1

def bye():
    print('Gone with the wind...')

ender = weakref.finalize(s1, bye)

print(ender.alive)

del s1

print(ender.alive)

s2 = 'spam'

print(ender.alive)
# Out:
# True
# True
# Gone with the wind...
# False
# Gone with the wind...
